# %% [markdown]
# # 调用线上模型
#
# ## 调用具体模型厂商的api
#
# ### 1.1deepseek
#
# 调用大模型涉及到三个重要参数
# baseurl、model_name、apikey
#
# 例1.很重要要把这三个放到配置文件里

# %%
import os
from http.client import responses

from dotenv import load_dotenv
from langchain_deepseek import ChatDeepSeek

#1.读取.env里的信息，相关的环境变量要以env里的为准
load_dotenv(override= True)

DEEPSEEK_API_KEY=os.getenv("DEEPSEEK_API_KEY")
DEEPSEEK_BASE_URL=os.getenv("DEEPSEEK_BASE_URL")

#2.模型的初始化
llm_deepseek=ChatDeepSeek(
    model='deepseek-v4-flash',
    api_key= DEEPSEEK_API_KEY,
    api_base=DEEPSEEK_BASE_URL
)

#3.模型的调用
response=llm_deepseek.invoke("请用一句话介绍你自己")
print(response)
# Out:
# content='我是一个乐于助人的AI助手，可以回答问题、提供建议并协助你完成各种任务。' additional_kwargs={'refusal': None, 'reasoning_content': '我们需要回答用户中文：“请用一句话介绍你自己”。需要一句话。我们需要作为 AI 助手。需要简洁。可以：“我是一个乐于助人的人工智能助手，可以回答问题、提供建议并协助处理各种任务。” 一句话。确保中文。也许需要更准确：我是由深度求索开发的AI助手？ No need maybe. Since system says accessed via API. We are DeepSeek? Actually identity? We shouldn\'t claim if not sure. But the prompt asks self-intro. We can say: "我是一个AI助手，能用中文和你交流并尽力回答你的问题、协助你完成各种任务。" 一句话。符合。注意“一句话”不要多句。 Final only. '} response_metadata={'token_usage': {'completion_tokens': 162, 'prompt_tokens': 35, 'total_tokens': 197, 'completion_tokens_details': {'accepted_prediction_tokens': None, 'audio_tokens': None, 'reasoning_tokens': 142, 'rejected_prediction_tokens': None}, 'prompt_tokens_details': {'audio_tokens': None, 'cached_tokens': 0}, 'prompt_cache_hit_tokens': 0, 'prompt_cache_miss_tokens': 35}, 'model_provider': 'deepseek', 'model_name': 'deepseek-flash', 'system_fingerprint': 'aeb56401ca74e127821c4f9126dcb669', 'id': '3c2b6d52-600c-4f47-8bc0-2b57f55840da', 'finish_reason': 'stop', 'logprobs': None} id='lc_run--01a08a1e-1235-7640-a995-336c445818ed-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 35, 'output_tokens': 162, 'total_tokens': 197, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 142}}

# %% [markdown]
# # 举例2：对1的优化

# %%
import os
from http.client import responses

from dotenv import load_dotenv
from langchain_deepseek import ChatDeepSeek

#1.读取.env里的信息，相关的环境变量要以env里的为准
load_dotenv(override= True)

# DEEPSEEK_API_KEY=os.getenv("DEEPSEEK_API_KEY")
# DEEPSEEK_BASE_URL=os.getenv("DEEPSEEK_BASE_URL")

#2.模型的初始化
llm_deepseek=ChatDeepSeek(
    model='deepseek-v4-flash',
    # api_key= DEEPSEEK_API_KEY,在初始化时系统自动赋值了
    # api_base=DEEPSEEK_BASE_URL
)

#3.模型的调用
response=llm_deepseek.invoke("请用一句话介绍你自己")
print(response)
